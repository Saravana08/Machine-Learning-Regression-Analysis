# %% [markdown]
# # Linear Regression

# %%
#import libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = {('Bikecc'):[100,150,200,250],('Price'):[10000,15000,20000,25000]}
print(dataset)
data = pd.DataFrame(dataset)
print(data)
# Out:
# {'Bikecc': [100, 150, 200, 250], 'Price': [10000, 15000, 20000, 25000]}
#    Bikecc  Price
# 0     100  10000
# 1     150  15000
# 2     200  20000
# 3     250  25000

# %% [markdown]
# # Intercept & Bias

# %%
# initializing our inputs and outputs
X = data['Bikecc'].values
Y = data['Price'].values
# mean of our inputs and outputs
x_mean = np.mean(X)
y_mean = np.mean(Y)
#total number of values
n = len(X)
# using the formula to calculate the b1 and b0
numerator = 0
denominator = 0
for i in range(n):
    numerator += (X[i] - x_mean) * (Y[i] - y_mean)
    denominator += (X[i] - x_mean) ** 2
    
b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)
#printing the coefficient
print(b1, b0)
# Out:
# 100.0 0.0

# %% [markdown]
# # Lets plot it graphically

# %%
#plotting values 
x_max = np.max(X) + 100
x_min = np.min(X) - 100
#calculating line values of x and y
x = np.linspace(x_min, x_max, 1000)
y = b0 + b1 * x
#plotting line 
plt.plot(x, y, color='#00ff00', label='Linear Regression')
#plot the data point
plt.scatter(X, Y, color='#ff0000', label='Data Point')
# x-axis label
plt.xlabel('Head Size (cm^3)')
#y-axis label
plt.ylabel('Brain Weight (grams)')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluate the Model

# %%
# Root mean squared error and coefficient of Determination (R² Score).

# %%
rmse = 0
for i in range(n):
    y_pred=  b0 + b1* X[i]
    rmse += (Y[i] - y_pred) ** 2
    
rmse = np.sqrt(rmse/n)
print(rmse)
# Out:
# 0.0

# %%
# R square = SSR/SST 
# SST is the total sum of squares and SSR is the total sum of squares of residuals.

# %%
# R² Score usually ranges from 0 to 1.
# It will also become negative if the model is completely wrong. Now we will find the R² Score.

# %%
sumofsquares = 0
sumofresiduals = 0
for i in range(n) :
    y_pred = b0 + b1 * X[i]
    sumofsquares += (Y[i] - y_mean) ** 2
    sumofresiduals += (Y[i] - y_pred) **2
    
score  = 1 - (sumofresiduals/sumofsquares)
print(score)
# Out:
# 1.0

# %%
# when the score is 1 it means its the best model

# %% [markdown]
# # Using Machine learning Models

# %%
# Loading the dataset

import os
os.chdir('C://Users//kingm//Desktop//Courses//Day 9')
pd.options.display.max_columns=999                      # To Display maximum rows or columns
data=pd.read_csv('train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.columns # To check all the columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data.head() # checking the head of the data
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# Doing the Exploratory Analysis
import matplotlib.pyplot as plt


plt.scatter(data['TotalBsmtSF'],data['SalePrice'])     # Scatterplot with Price & TotalBsmtSF to check the linear relation

# %%
data.head() # checking the head of the data
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
plt.bar(data['MSZoning'],data['SalePrice'])      # It seems RL is trending towars High Price,
 #this is how we check the linear relation in categorical variables
# Out:
# <Container object of 1460 artists>

# %%
# Exploring the dataset
print(data.describe())       # checking the descriptive statistics
data.isnull().sum()          # checking the null values
data['LotFrontage'].mean()    # checking the mean of the columns
data['LotFrontage'].fillna(70,inplace=True)      # imputing the missing values for our model
data.isnull().sum()           # Checking if there is any null values present in the data
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# Checking for Outliers

plt.boxplot(data['LotFrontage'])
plt.show()

# %%
data= data.loc[data['LotFrontage'] <100]   # Updated the values which are outliers
plt.boxplot(data['LotFrontage'])  # now we can check the updated plot
plt.show()

# %%
data= data.loc[data['LotFrontage'] >40]    # Similarly we are removing outliers from the bottom
plt.boxplot(data['LotFrontage'])  # now we can check the updated plot
plt.show()

# %%
x = data[['MSSubClass','MSZoning','LotFrontage','LotArea']]   # taking the three variables to plot the regression line
y = data['SalePrice']

# %%
pd.get_dummies(x).head()     # One Hot Encoding of the dataset
# Out:
#    MSSubClass  LotFrontage  LotArea  MSZoning_C (all)  MSZoning_FV  \
# 0          60         65.0     8450                 0            0
# 1          20         80.0     9600                 0            0
# 2          60         68.0    11250                 0            0
# 3          70         60.0     9550                 0            0
# 4          60         84.0    14260                 0            0
#
#    MSZoning_RH  MSZoning_RL  MSZoning_RM
# 0            0            1            0
# 1            0            1            0
# 2            0            1            0
# 3            0            1            0
# 4            0            1            0

# %%
x= pd.get_dummies(x)        # Updating the new columns

# %%
from sklearn.linear_model import LinearRegression           # Loading the Linear Regression from the scikit learn library
model = LinearRegression()
from sklearn.model_selection import train_test_split        # doing the Train-Test Split to check our accuracy

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3)
model.fit(xtrain,ytrain)                                    # Fitting the model with our data
pred = model.predict(xtest)                                 #Predicing the test values

from sklearn.metrics import mean_squared_error,r2_score      # Checking the mean square error

mean_squared_error(ytest,pred)
model.score(xtrain,ytrain)                                   # Checking the R2 of our Model which should be close to 1
# Out:
# 0.25201851403250786
